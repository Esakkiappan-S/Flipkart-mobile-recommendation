# %% [markdown]
# Machine Learning - ML

# %%
# !pip install spacy
import spacy
# Spacy - Number, range, Which Doc

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 18.8 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd
df = pd.read_csv("Flipkart_cleaned_mobile_data_reviews_with_textblob_sentiment_analysis.csv")

# %%
df.head()
# Out:
#             Product_name        Product ID  \
# 0  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
# 1  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
# 2  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
# 3  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
# 4  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
#
#                                          Review Text  Rating  \
# 0                                         Osm camera       4
# 1                                   Over All awesome       5
# 2  Good  Samsung Galaxy A14 5g  Dark Red 6 128   ...       5
# 3                                            Awesome       5
# 4  Classy and minimal design is amazing Performan...       5
#
#                                        Reviews_token  \
# 0                                  ['osm', 'camera']
# 1                                        ['awesome']
# 2  ['good', 'samsung', 'galaxy', 'a14', '5g', 'da...
# 3                                        ['awesome']
# 4  ['classy', 'minimal', 'design', 'amazing', 'pe...
#
# ...

# %%
x=df["Review Text"]
y=df["TextBlob_Sentiment"]

# %%
nlp = spacy.load("en_core_web_md")
x=[nlp(i).vector for i in x]

# %%
# Principal Component Analysis -Reduce the number of features: in your dataset while retaining as much of the important information as possible.
from sklearn.decomposition import PCA
enco=PCA(n_components=10)
x_pca=enco.fit_transform(x)

# %%
x_pca[0].shape
# Out:
# (10,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x_pca, y, test_size=0.3, random_state=42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((315, 10), (135, 10), (315,), (135,))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
model=RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9259259259259259

# %%
df.head()
# Out:
#             Product_name        Product ID  \
# 0  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
# 1  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
# 2  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
# 3  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
# 4  SAMSUNG Galaxy A14 5G  MOBGHT8UUUNXNYZ4
#
#                                          Review Text  Rating  \
# 0                                         Osm camera       4
# 1                                   Over All awesome       5
# 2  Good  Samsung Galaxy A14 5g  Dark Red 6 128   ...       5
# 3                                            Awesome       5
# 4  Classy and minimal design is amazing Performan...       5
#
#                                        Reviews_token  \
# 0                                  ['osm', 'camera']
# 1                                        ['awesome']
# 2  ['good', 'samsung', 'galaxy', 'a14', '5g', 'da...
# 3                                        ['awesome']
# 4  ['classy', 'minimal', 'design', 'amazing', 'pe...
#
# ...
